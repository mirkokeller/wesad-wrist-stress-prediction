# %% [markdown]
# # Results Notebook
#
# This notebook is reserved for:
# - Model training results
# - Performance metrics
# - Confusion matrices
# - ROC curves
# - Feature importance analysis
# - Final figures for the report
#
# ## Current Data Status

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

import numpy as np
import pandas as pd
from collections import Counter

# Load features
data = np.load('../data/03_processed/features.npz', allow_pickle=True)
X = data['X']
y = data['y']
subject = data['subject']
feature_names = list(data['feature_names'])

# %%
print("=== DATASET SUMMARY ===\n")
print(f"Features: {X.shape[0]:,} samples × {X.shape[1]} features")
print(f"Labels: {len(np.unique(y))} classes ({sorted(set(y))})")
print(f"Subjects: {len(set(subject))}")
print()
print("Label distribution:", dict(Counter(y)))
print()
print("Subject distribution:", dict(Counter(subject)))

# %% [markdown]
# ## TODO - Add Analysis Here
#
# Next steps:
# 1. Train models (**NO** Decision Tree (DT), Random Forest (RF), AdaBoost (AB)Linear Discriminant Analysis (LDA), and k-Nearest Neighbour (kNN).) Because the project state not to use the same models as the paper, I will use Support Vector Machine (SVM), Logistic Regression (LR), and Multilayer Perceptron (MLP) instead.
#
# 2. Perform LOSO cross-validation
# 3. Compute metrics (accuracy, precision, recall, F1)
# 4. Visualize results
# 5. Generate report figures
